# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from collections import defaultdict

# %%
pd.set_option("display.max_rows", None)

# %%
# %matplotlib inline

# %% [markdown]
# # Mother Qualification and Previous Qualification vs Target

# %%
mother_qual_df = pd.read_csv('reformatted_mother_previous_qual_groupby_result.csv')

# %%
mother_qual_df.head()
# Out:
#                            mother qualification  \
# 0  Secondary Education - 12th Year of Schooling
# 1  Secondary Education - 12th Year of Schooling
# 2  Secondary Education - 12th Year of Schooling
# 3  Secondary Education - 12th Year of Schooling
# 4  Secondary Education - 12th Year of Schooling
#
#                          previous qualification    target  count
# 0  Secondary Education - 12th Year of Schooling  Graduate    499
# 1  Secondary Education - 12th Year of Schooling   Dropout    238
# 2  Secondary Education - 12th Year of Schooling  Enrolled    185
# 3           Technological specialization course  Graduate     26
# 4           Technological specialization course   Dropout     26

# %%
mother_qual_df = mother_qual_df.sort_values(by=['previous qualification', 'mother qualification', 'target'])
mother_qual_df
# Out:
#                                mother qualification  \
# 51     Basic Education 2nd Cycle (6th/7th/8th Year)
# 53     Basic Education 2nd Cycle (6th/7th/8th Year)
# 52     Basic Education 2nd Cycle (6th/7th/8th Year)
# 36   Basic Education 3rd Cycle (9th/10th/11th Year)
# 38   Basic Education 3rd Cycle (9th/10th/11th Year)
# 37   Basic Education 3rd Cycle (9th/10th/11th Year)
# 18         Basic education 1st cycle (4th/5th year)
# 20         Basic education 1st cycle (4th/5th year)
# 19         Basic education 1st cycle (4th/5th year)
# 69                        Higher Education - Degree
# 71                        Higher Education - Degree
# 70                        Higher Education - Degree
# 12     Secondary Education - 12th Year of Schooling
# 14     Secondary Education - 12th Year of Schooling
# 13     Secondary Education - 12th Year of Schooling
# 55     Basic Education 2nd Cycle (6th/7th/8th Year)
# 56     Basic Education 2nd Cycle (6th/7th/8th Year)
# ...

# %%
mother_qualification_target_count = defaultdict(list)

for index, row in mother_qual_df.iterrows():
  key = f"{row['previous qualification']}-{row['target']}"
  mother_qualification_target_count[key].append(row['count'])
mother_qualification_target_count
# Out:
# defaultdict(list,
#             {'Basic Education 3rd Cycle (9th/10th/11th Year)-Dropout': [14,
#               21,
#               44,
#               4,
#               10],
#              'Basic Education 3rd Cycle (9th/10th/11th Year)-Enrolled': [1,
#               4,
#               6,
#               0,
#               2],
#              'Basic Education 3rd Cycle (9th/10th/11th Year)-Graduate': [5,
#               7,
#               26,
#               1,
#               2],
#              'Higher Education - Degree-Dropout': [2, 14, 19, 14, 13],
#              'Higher Education - Degree-Enrolled': [0, 1, 3, 0, 0],
#              'Higher Education - Degree-Graduate': [2, 7, 20, 7, 7],
#              "Higher Education - Master's-Dropout": [0, 0, 0, 2, 0],
#              "Higher Education - Master's-Enrolled": [0, 0, 0, 0, 0],
#              "Higher Education - Master's-Graduate": [0, 0, 0, 2, 0],
#              'Other-Dropout': [0, 0, 14, 0, 0],
# ...

# %%
def create_mother_qual_graph():
  groups = ['6th/7th/8th Year', '9th/10th/11th Year', '4th/5th year', 'Degree', '12th Year']

  with sns.axes_style("white"):
    sns.set_style("ticks")
    sns.set_context("talk")

    bar_width = 0.10
    epsilon = .015
    line_width = 1
    opacity = 0.7
    bar1_positions = np.arange(5)
    bar2_positions = bar1_positions + bar_width
    bar3_positions = bar2_positions + bar_width
    bar4_positions = bar3_positions + bar_width
    bar5_positions = bar4_positions + bar_width
    bar6_positions = bar5_positions + bar_width
    bar7_positions = bar6_positions + bar_width
    plt.figure(figsize=(12, 12))
    # Basic Education 3rd Cycle (9th/10th/11th Year)
    plt.bar(bar1_positions, mother_qualification_target_count['Basic Education 3rd Cycle (9th/10th/11th Year)-Dropout'], bar_width,
                              color='#548282',
                              label='9th/10th/11th Year-Dropout')
    plt.bar(bar1_positions, mother_qualification_target_count['Basic Education 3rd Cycle (9th/10th/11th Year)-Enrolled'], bar_width-epsilon,
                              bottom=mother_qualification_target_count['Basic Education 3rd Cycle (9th/10th/11th Year)-Dropout'],
                              alpha=opacity,
                              color='white',
                              edgecolor='#548282',
                              linewidth=line_width,
                              hatch='//',
                              label='9th/10th/11th Year-Enrolled')
    plt.bar(bar1_positions, mother_qualification_target_count['Basic Education 3rd Cycle (9th/10th/11th Year)-Graduate'], bar_width-epsilon,
                               bottom=np.array(mother_qualification_target_count['Basic Education 3rd Cycle (9th/10th/11th Year)-Enrolled'])+np.array(mother_qualification_target_count['Basic Education 3rd Cycle (9th/10th/11th Year)-Dropout']),
                               alpha=opacity,
                               color='white',
                               edgecolor='#548282',
                               linewidth=line_width,
                               hatch='0',
                               label='9th/10th/11th Year-Graduate')


    # Higher Education - Degree
    plt.bar(bar2_positions, mother_qualification_target_count['Higher Education - Degree-Dropout'], bar_width,
                              color='#5E5A58',
                              label='Degree-Dropout')
    plt.bar(bar2_positions, mother_qualification_target_count['Higher Education - Degree-Enrolled'], bar_width-epsilon,
                              bottom=mother_qualification_target_count['Higher Education - Degree-Dropout'],
                              color="white",
                              hatch='//',
                              edgecolor='#5E5A58',
                              ecolor="#5E5A58",
                              linewidth=line_width,
                              label='Degree-Enrolled')
    plt.bar(bar2_positions, mother_qualification_target_count['Higher Education - Degree-Graduate'], bar_width-epsilon,
                               bottom=np.array(mother_qualification_target_count['Higher Education - Degree-Enrolled'])+np.array(mother_qualification_target_count['Higher Education - Degree-Dropout']),
                               color="white",
                               hatch='0',
                               edgecolor='#5E5A58',
                               ecolor="#5E5A58",
                               linewidth=line_width,
                               label='Degree-Graduate')

    # Higher Education - Master's
    plt.bar(bar3_positions, mother_qualification_target_count["Higher Education - Master's-Dropout"], bar_width,
                              color='#A4CACA',
                              label="Master's-Dropout")
    plt.bar(bar3_positions, mother_qualification_target_count["Higher Education - Master's-Enrolled"], bar_width-epsilon,
                              bottom=mother_qualification_target_count["Higher Education - Master's-Dropout"],
                              color="white",
                              hatch='//',
                              edgecolor='#A4CACA',
                              ecolor="#A4CACA",
                              linewidth=line_width,
                              label="Master's-Enrolled")
    plt.bar(bar3_positions, mother_qualification_target_count["Higher Education - Master's-Graduate"], bar_width-epsilon,
                               bottom=np.array(mother_qualification_target_count["Higher Education - Master's-Enrolled"])+np.array(mother_qualification_target_count["Higher Education - Master's-Dropout"]),
                               color="white",
                               hatch='0',
                               edgecolor='#A4CACA',
                               ecolor="#A4CACA",
                               linewidth=line_width,
                               label="Master's-Graduate")

    # Other
    plt.bar(bar4_positions, mother_qualification_target_count['Other-Dropout'], bar_width,
                              color='#FF8B8B',
                              label='Other-Dropout')
    plt.bar(bar4_positions, mother_qualification_target_count['Other-Enrolled'], bar_width-epsilon,
                              bottom=mother_qualification_target_count['Other-Dropout'],
                              color="white",
                              hatch='//',
                              edgecolor='#FF8B8B',
                              ecolor="#FF8B8B",
                              linewidth=line_width,
                              label='Other-Enrolled')
    plt.bar(bar4_positions, mother_qualification_target_count['Other-Graduate'], bar_width-epsilon,
                               bottom=np.array(mother_qualification_target_count['Other-Enrolled'])+np.array(mother_qualification_target_count['Other-Dropout']),
                               color="white",
                               hatch='0',
                               edgecolor='#FF8B8B',
                               ecolor="#FF8B8B",
                               linewidth=line_width,
                               label='Other-Graduate')

    # Professional higher technical course
    plt.bar(bar5_positions, mother_qualification_target_count['Professional higher technical course-Dropout'], bar_width,
                              color='#FFC000',
                              label='Professional higher technical course-Dropout')
    plt.bar(bar5_positions, mother_qualification_target_count['Professional higher technical course-Enrolled'], bar_width-epsilon,
                              bottom=mother_qualification_target_count['Professional higher technical course-Dropout'],
                              color="white",
                              hatch='//',
                              edgecolor='#FFC000',
                              ecolor="#FFC000",
                              linewidth=line_width,
                              label='Professional higher technical course-Enrolled')
    plt.bar(bar5_positions, mother_qualification_target_count['Professional higher technical course-Graduate'], bar_width-epsilon,
                               bottom=np.array(mother_qualification_target_count['Professional higher technical course-Enrolled'])+np.array(mother_qualification_target_count['Professional higher technical course-Dropout']),
                               color="white",
                               hatch='0',
                               edgecolor='#FFC000',
                               ecolor="#FFC000",
                               linewidth=line_width,
                               label='Professional higher technical course-Graduate')

    # Secondary Education - 12th Year of Schooling
    plt.bar(bar6_positions, mother_qualification_target_count['Secondary Education - 12th Year of Schooling-Dropout'], bar_width,
                              color='#004771',
                              label='12th Year of Schooling-Dropout')
    plt.bar(bar6_positions, mother_qualification_target_count['Secondary Education - 12th Year of Schooling-Enrolled'], bar_width-epsilon,
                              bottom=mother_qualification_target_count['Secondary Education - 12th Year of Schooling-Dropout'],
                              color="white",
                              hatch='//',
                              edgecolor='#004771',
                              ecolor="#004771",
                              linewidth=line_width,
                              label='12th Year of Schooling-Enrolled')
    plt.bar(bar6_positions, mother_qualification_target_count['Secondary Education - 12th Year of Schooling-Graduate'], bar_width-epsilon,
                               bottom=np.array(mother_qualification_target_count['Secondary Education - 12th Year of Schooling-Enrolled'])+np.array(mother_qualification_target_count['Secondary Education - 12th Year of Schooling-Dropout']),
                               color="white",
                               hatch='0',
                               edgecolor='#004771',
                               ecolor="#004771",
                               linewidth=line_width,
                               label='12th Year of Schooling-Graduate')

    # Technological specialization course
    plt.bar(bar7_positions, mother_qualification_target_count['Technological specialization course-Dropout'], bar_width,
                              color='#745974',
                              label='Technological specialization course-Dropout')
    plt.bar(bar7_positions, mother_qualification_target_count['Technological specialization course-Enrolled'], bar_width-epsilon,
                              bottom=mother_qualification_target_count['Technological specialization course-Dropout'],
                              color="white",
                              hatch='//',
                              edgecolor='#745974',
                              ecolor="#745974",
                              linewidth=line_width,
                              label='Technological specialization course-Enrolled')
    plt.bar(bar7_positions, mother_qualification_target_count['Technological specialization course-Graduate'], bar_width-epsilon,
                               bottom=np.array(mother_qualification_target_count['Technological specialization course-Enrolled'])+np.array(mother_qualification_target_count['Technological specialization course-Dropout']),
                               color="white",
                               hatch='0',
                               edgecolor='#745974',
                               ecolor="#745974",
                               linewidth=line_width,
                               label='Technological specialization course-Graduate')

    plt.title("Mother Qualification influence on Student Previous Qualifications and Target")
    plt.xticks(bar7_positions, groups, rotation=45)
    plt.xlabel("Mother Qualifications")
    plt.ylabel('Count')
    plt.legend(title="Students' Previous Qualifications", bbox_to_anchor=(0.5, 1.15), ncol=2)
    sns.despine()
    plt.show()

# %%
create_mother_qual_graph()
# Out:
# <ipython-input-37-e1eca068ec36>:32: MatplotlibDeprecationWarning: hatch must consist of a string of "*+-./OX\ox|" or None, but found the following invalid values "0". Passing invalid values is deprecated since 3.4 and will become an error in 3.8.
#   plt.bar(bar1_positions, mother_qualification_target_count['Basic Education 3rd Cycle (9th/10th/11th Year)-Graduate'], bar_width-epsilon,
# <ipython-input-37-e1eca068ec36>:54: MatplotlibDeprecationWarning: hatch must consist of a string of "*+-./OX\ox|" or None, but found the following invalid values "0". Passing invalid values is deprecated since 3.4 and will become an error in 3.8.
#   plt.bar(bar2_positions, mother_qualification_target_count['Higher Education - Degree-Graduate'], bar_width-epsilon,
# ...

# %% [markdown]
# # Father Qualification and Previous Qualification vs Target

# %%
father_qual_df = pd.read_csv('reformatted_father_previous_qual_groupby_result.csv')
father_qual_df.head()
# Out:
#                        father qualification  \
# 0  Basic education 1st cycle (4th/5th year)
# 1  Basic education 1st cycle (4th/5th year)
# 2  Basic education 1st cycle (4th/5th year)
# 3  Basic education 1st cycle (4th/5th year)
# 4  Basic education 1st cycle (4th/5th year)
#
#                            previous qualification    target  count
# 0    Secondary Education - 12th Year of Schooling  Graduate    481
# 1    Secondary Education - 12th Year of Schooling   Dropout    323
# 2    Secondary Education - 12th Year of Schooling  Enrolled    175
# 3  Basic Education 3rd Cycle (9th/10th/11th Year)   Dropout     43
# 4  Basic Education 3rd Cycle (9th/10th/11th Year)  Graduate     24

# %%
father_qual_df = father_qual_df.sort_values(by=['previous qualification', 'father qualification', 'target'])
father_qual_df
# Out:
#                                father qualification  \
# 51     Basic Education 2nd Cycle (6th/7th/8th Year)
# 53     Basic Education 2nd Cycle (6th/7th/8th Year)
# 52     Basic Education 2nd Cycle (6th/7th/8th Year)
# 21   Basic Education 3rd Cycle (9th/10th/11th Year)
# 23   Basic Education 3rd Cycle (9th/10th/11th Year)
# 22   Basic Education 3rd Cycle (9th/10th/11th Year)
# 3          Basic education 1st cycle (4th/5th year)
# 5          Basic education 1st cycle (4th/5th year)
# 4          Basic education 1st cycle (4th/5th year)
# 103                       Higher Education - Degree
# 104                       Higher Education - Degree
# 102                       Higher Education - Degree
# 36     Secondary Education - 12th Year of Schooling
# 37     Secondary Education - 12th Year of Schooling
# 38     Secondary Education - 12th Year of Schooling
# 55     Basic Education 2nd Cycle (6th/7th/8th Year)
# 56     Basic Education 2nd Cycle (6th/7th/8th Year)
# ...

# %%
father_qualification_target_count = defaultdict(list)

for index, row in father_qual_df.iterrows():
  key = f"{row['previous qualification']}-{row['target']}"
  father_qualification_target_count[key].append(row['count'])
father_qualification_target_count
# Out:
# defaultdict(list,
#             {'Basic Education 3rd Cycle (9th/10th/11th Year)-Dropout': [13,
#               20,
#               43,
#               0,
#               18],
#              'Basic Education 3rd Cycle (9th/10th/11th Year)-Enrolled': [2,
#               4,
#               6,
#               0,
#               0],
#              'Basic Education 3rd Cycle (9th/10th/11th Year)-Graduate': [3,
#               10,
#               24,
#               0,
#               4],
#              'Higher Education - Degree-Dropout': [7, 12, 19, 7, 12],
#              'Higher Education - Degree-Enrolled': [0, 1, 2, 0, 1],
#              'Higher Education - Degree-Graduate': [8, 7, 19, 6, 2],
#              "Higher Education - Master's-Dropout": [0, 0, 0, 2, 0],
#              "Higher Education - Master's-Enrolled": [0, 0, 0, 1, 0],
#              "Higher Education - Master's-Graduate": [0, 0, 0, 1, 0],
#              'Higher education - degree (1st cycle)-Dropout': [0, 0, 0, 3, 3],
# ...

# %%
def create_father_qual_graph():
  groups = ['6th/7th/8th Year', '9th/10th/11th Year', '4th/5th year', 'Degree', '12th Year']

  with sns.axes_style("white"):
    sns.set_style("ticks")
    sns.set_context("talk")

    bar_width = 0.10
    epsilon = .015
    line_width = 1
    opacity = 0.7
    bar1_positions = np.arange(5)
    bar2_positions = bar1_positions + bar_width
    bar3_positions = bar2_positions + bar_width
    bar4_positions = bar3_positions + bar_width
    bar5_positions = bar4_positions + bar_width
    bar6_positions = bar5_positions + bar_width
    bar7_positions = bar6_positions + bar_width
    bar8_positions = bar7_positions + bar_width
    plt.figure(figsize=(12, 12))
    # Basic Education 3rd Cycle (9th/10th/11th Year)
    plt.bar(bar1_positions, father_qualification_target_count['Basic Education 3rd Cycle (9th/10th/11th Year)-Dropout'], bar_width,
                              color='#548282',
                              label='9th/10th/11th Year-Dropout')
    plt.bar(bar1_positions, father_qualification_target_count['Basic Education 3rd Cycle (9th/10th/11th Year)-Enrolled'], bar_width-epsilon,
                              bottom=father_qualification_target_count['Basic Education 3rd Cycle (9th/10th/11th Year)-Dropout'],
                              alpha=opacity,
                              color='white',
                              edgecolor='#548282',
                              linewidth=line_width,
                              hatch='//',
                              label='9th/10th/11th Year-Enrolled')
    plt.bar(bar1_positions, father_qualification_target_count['Basic Education 3rd Cycle (9th/10th/11th Year)-Graduate'], bar_width-epsilon,
                               bottom=np.array(father_qualification_target_count['Basic Education 3rd Cycle (9th/10th/11th Year)-Enrolled'])+np.array(father_qualification_target_count['Basic Education 3rd Cycle (9th/10th/11th Year)-Dropout']),
                               alpha=opacity,
                               color='white',
                               edgecolor='#548282',
                               linewidth=line_width,
                               hatch='0',
                               label='9th/10th/11th Year-Graduate')


    # Higher Education - Degree
    plt.bar(bar2_positions, father_qualification_target_count['Higher Education - Degree-Dropout'], bar_width,
                              color='#5E5A58',
                              label='Degree-Dropout')
    plt.bar(bar2_positions, father_qualification_target_count['Higher Education - Degree-Enrolled'], bar_width-epsilon,
                              bottom=father_qualification_target_count['Higher Education - Degree-Dropout'],
                              color="white",
                              hatch='//',
                              edgecolor='#5E5A58',
                              ecolor="#5E5A58",
                              linewidth=line_width,
                              label='Degree-Enrolled')
    plt.bar(bar2_positions, father_qualification_target_count['Higher Education - Degree-Graduate'], bar_width-epsilon,
                               bottom=np.array(father_qualification_target_count['Higher Education - Degree-Enrolled'])+np.array(father_qualification_target_count['Higher Education - Degree-Dropout']),
                               color="white",
                               hatch='0',
                               edgecolor='#5E5A58',
                               ecolor="#5E5A58",
                               linewidth=line_width,
                               label='Degree-Graduate')

    # Higher Education - Master's
    plt.bar(bar3_positions, father_qualification_target_count["Higher Education - Master's-Dropout"], bar_width,
                              color='#A4CACA',
                              label="Master's-Dropout")
    plt.bar(bar3_positions, father_qualification_target_count["Higher Education - Master's-Enrolled"], bar_width-epsilon,
                              bottom=father_qualification_target_count["Higher Education - Master's-Dropout"],
                              color="white",
                              hatch='//',
                              edgecolor='#A4CACA',
                              ecolor="#A4CACA",
                              linewidth=line_width,
                              label="Master's-Enrolled")
    plt.bar(bar3_positions, father_qualification_target_count["Higher Education - Master's-Graduate"], bar_width-epsilon,
                               bottom=np.array(father_qualification_target_count["Higher Education - Master's-Enrolled"])+np.array(father_qualification_target_count["Higher Education - Master's-Dropout"]),
                               color="white",
                               hatch='0',
                               edgecolor='#A4CACA',
                               ecolor="#A4CACA",
                               linewidth=line_width,
                               label="Master's-Graduate")

    # Other
    plt.bar(bar4_positions, father_qualification_target_count['Other-Dropout'], bar_width,
                              color='#FF8B8B',
                              label='Other-Dropout')
    plt.bar(bar4_positions, father_qualification_target_count['Other-Enrolled'], bar_width-epsilon,
                              bottom=father_qualification_target_count['Other-Dropout'],
                              color="white",
                              hatch='//',
                              edgecolor='#FF8B8B',
                              ecolor="#FF8B8B",
                              linewidth=line_width,
                              label='Other-Enrolled')
    plt.bar(bar4_positions, father_qualification_target_count['Other-Graduate'], bar_width-epsilon,
                               bottom=np.array(father_qualification_target_count['Other-Enrolled'])+np.array(father_qualification_target_count['Other-Dropout']),
                               color="white",
                               hatch='0',
                               edgecolor='#FF8B8B',
                               ecolor="#FF8B8B",
                               linewidth=line_width,
                               label='Other-Graduate')

    # Professional higher technical course
    plt.bar(bar5_positions, father_qualification_target_count['Professional higher technical course-Dropout'], bar_width,
                              color='#FFC000',
                              label='Professional higher technical course-Dropout')
    plt.bar(bar5_positions, father_qualification_target_count['Professional higher technical course-Enrolled'], bar_width-epsilon,
                              bottom=father_qualification_target_count['Professional higher technical course-Dropout'],
                              color="white",
                              hatch='//',
                              edgecolor='#FFC000',
                              ecolor="#FFC000",
                              linewidth=line_width,
                              label='Professional higher technical course-Enrolled')
    plt.bar(bar5_positions, father_qualification_target_count['Professional higher technical course-Graduate'], bar_width-epsilon,
                               bottom=np.array(father_qualification_target_count['Professional higher technical course-Enrolled'])+np.array(father_qualification_target_count['Professional higher technical course-Dropout']),
                               color="white",
                               hatch='0',
                               edgecolor='#FFC000',
                               ecolor="#FFC000",
                               linewidth=line_width,
                               label='Professional higher technical course-Graduate')

    # Secondary Education - 12th Year of Schooling
    plt.bar(bar6_positions, father_qualification_target_count['Secondary Education - 12th Year of Schooling-Dropout'], bar_width,
                              color='#004771',
                              label='12th Year of Schooling-Dropout')
    plt.bar(bar6_positions, father_qualification_target_count['Secondary Education - 12th Year of Schooling-Enrolled'], bar_width-epsilon,
                              bottom=father_qualification_target_count['Secondary Education - 12th Year of Schooling-Dropout'],
                              color="white",
                              hatch='//',
                              edgecolor='#004771',
                              ecolor="#004771",
                              linewidth=line_width,
                              label='12th Year of Schooling-Enrolled')
    plt.bar(bar6_positions, father_qualification_target_count['Secondary Education - 12th Year of Schooling-Graduate'], bar_width-epsilon,
                               bottom=np.array(father_qualification_target_count['Secondary Education - 12th Year of Schooling-Enrolled'])+np.array(father_qualification_target_count['Secondary Education - 12th Year of Schooling-Dropout']),
                               color="white",
                               hatch='0',
                               edgecolor='#004771',
                               ecolor="#004771",
                               linewidth=line_width,
                               label='12th Year of Schooling-Graduate')

    # Technological specialization course
    plt.bar(bar7_positions, father_qualification_target_count['Technological specialization course-Dropout'], bar_width,
                              color='#745974',
                              label='Technological specialization course-Dropout')
    plt.bar(bar7_positions, father_qualification_target_count['Technological specialization course-Enrolled'], bar_width-epsilon,
                              bottom=father_qualification_target_count['Technological specialization course-Dropout'],
                              color="white",
                              hatch='//',
                              edgecolor='#745974',
                              ecolor="#745974",
                              linewidth=line_width,
                              label='Technological specialization course-Enrolled')
    plt.bar(bar7_positions, father_qualification_target_count['Technological specialization course-Graduate'], bar_width-epsilon,
                               bottom=np.array(father_qualification_target_count['Technological specialization course-Enrolled'])+np.array(father_qualification_target_count['Technological specialization course-Dropout']),
                               color="white",
                               hatch='0',
                               edgecolor='#745974',
                               ecolor="#745974",
                               linewidth=line_width,
                               label='Technological specialization course-Graduate')

    # Higher education - degree (1st cycle)
    plt.bar(bar8_positions, father_qualification_target_count['Higher education - degree (1st cycle)-Dropout'], bar_width,
                              color='#FF8B8B',
                              label='Higher education - degree (1st cycle)-Dropout')
    plt.bar(bar8_positions, father_qualification_target_count['Higher education - degree (1st cycle)-Enrolled'], bar_width-epsilon,
                              bottom=father_qualification_target_count['Higher education - degree (1st cycle)-Dropout'],
                              color="white",
                              hatch='//',
                              edgecolor='#FF8B8B',
                              ecolor="#FF8B8B",
                              linewidth=line_width,
                              label='Higher education - degree (1st cycle)-Enrolled')
    plt.bar(bar8_positions, father_qualification_target_count['Higher education - degree (1st cycle)-Graduate'], bar_width-epsilon,
                               bottom=np.array(father_qualification_target_count['Higher education - degree (1st cycle)-Enrolled'])+np.array(father_qualification_target_count['Higher education - degree (1st cycle)-Dropout']),
                               color="white",
                               hatch='0',
                               edgecolor='#FF8B8B',
                               ecolor="#FF8B8B",
                               linewidth=line_width,
                               label='Higher education - degree (1st cycle)-Graduate')

    plt.title("Father Qualification influence on Student Previous Qualifications and Target")
    plt.xticks(bar8_positions, groups, rotation=45)
    plt.xlabel('Father Qualifications')
    plt.ylabel('Count')
    plt.legend(title="Students' Previous Qualifications", bbox_to_anchor=(0.5, 1.15), ncol=2)
    sns.despine()
    plt.show()

# %%
create_father_qual_graph()
# Out:
# <ipython-input-39-c8246ca03672>:33: MatplotlibDeprecationWarning: hatch must consist of a string of "*+-./OX\ox|" or None, but found the following invalid values "0". Passing invalid values is deprecated since 3.4 and will become an error in 3.8.
#   plt.bar(bar1_positions, father_qualification_target_count['Basic Education 3rd Cycle (9th/10th/11th Year)-Graduate'], bar_width-epsilon,
# <ipython-input-39-c8246ca03672>:55: MatplotlibDeprecationWarning: hatch must consist of a string of "*+-./OX\ox|" or None, but found the following invalid values "0". Passing invalid values is deprecated since 3.4 and will become an error in 3.8.
#   plt.bar(bar2_positions, father_qualification_target_count['Higher Education - Degree-Graduate'], bar_width-epsilon,
# ...
